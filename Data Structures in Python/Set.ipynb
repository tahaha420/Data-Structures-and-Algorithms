# %%
class Set :
    
    def __init__( self,seti,):
        self.seti = seti
        self.seti = list(dict.fromkeys(self.seti))
    
    def __len__( self ):
        print(len(self.seti))
    
    def __contains__( self, element ):
        return element in self.seti
    
    def add( self, element ):
        if element not in self :
            self.seti.append( element )
    
    def remove( self, element ):
        assert element in self, "The element must be in the set."
        self.seti.remove( element )
    
    def __eq__( self, setB ):
        if len( self ) != len( setB ) :
            return False
        else :
            return self.isSubsetOf( setB )
    
    def isSubsetOf( self, setB ):
        for element in self :
            if element not in setB :
                return False
        return True
    
    def union( self, setB ):
        newSet = Set()
        newSet.seti.extend( self.seti )
        for element in setB :
            if element not in self :
                newSet.seti.append( element )
        return newSet
    
    def interset( self, setB ):
        for i in self.seti:
            for j in setB:
                if(i==j):
                    print(i,end="", )
    
    def difference( self, setB ):
        for i in self.seti:
            if(i in setB):
                None
            else:
                print(i,end="",)
    
    def proper_subset(self,a,b):
        a=set(a)
        b=set(b)
        v=b.issubset(a)
        if(v==True):
            print("setB is subset of setA")
    
    def __str__(self):
        return str(self.seti)

a=list(input("Enter the list = "))
b=list(input("Enter the second list = "))
c=list(input("Enter the list for prper subset = "))
d=list(input("Enter the list for the set present in the set A = "))
v=Set(a)
v.__len__()
v.interset(b)
v.difference(b)
v.proper_subset(c,d)
